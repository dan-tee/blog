# %%
# <!-- collapse=True -->
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
sns.set_style('whitegrid')
sns.set_context('talk')

n_points = 100
x = np.linspace(0, 2, n_points)
y = np.array([0] * int(n_points/2) + list(x[:50]))

plt.figure(figsize=(5, 2))
plt.plot(x, y, linewidth=2)
plt.title('ridiculously simple data')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation

np.random.seed(0)
model = Sequential()
model.add(Dense(output_dim=1, input_dim=1, init="normal"))
model.add(Activation("relu"))
model.compile(loss='mean_squared_error', optimizer='sgd')

weights = model.layers[0].get_weights()
w0 = weights[0][0][0]
w1 = weights[1][0]
'net initialized with weigths w0: {w0:.2f}, w1: {w1:.2f}'.format(**locals())
# Out:
# Using Theano backend.
# //anaconda/lib/python3.5/site-packages/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")
# 'net initialized with weigths w0: 0.09, w1: 0.00'

# %%
from keras.callbacks import Callback

# %matplotlib notebook
epochs = 4000
batch_size = 100
n_batches = n_points / batch_size
intermediates = []

X_train = np.array(x, ndmin=2).T
Y_train = np.array(y, ndmin=2).T

class PlotLoss(Callback):
    def on_train_begin(self, logs={}):
        fig, (ax1, ax2) = plt.subplots(2, 1)
        self.fig = fig
        self.ax1 = ax1
        ax1.set_xlim([0, n_batches * epochs])
        #ax1.set_ylim([0, 1])
        self.ax2 = ax2
        
        self.losses = []
        self.i = 0

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        self.i += 1
        if self.i % 100 == 0:        
            if len(self.ax1.lines):
                self.ax1.lines[0].set_xdata(range(len(self.losses)))
                self.ax1.lines[0].set_ydata(self.losses)
            else:
                self.ax1.plot(self.losses)
                self.ax1.set_title('training loss')
                self.ax1.set_ylim([0, self.ax1.get_ylim()[1]])
            self.fig.canvas.draw()
            #print(model.layers[0].get_weights())
        
        if self.i % 100 == 0:        
            pred = model.predict(X_train)
            if len(self.ax2.lines):
                self.ax2.lines[0].set_xdata(x)
                self.ax2.lines[0].set_ydata(y)
                self.ax2.lines[1].set_xdata(x)
                self.ax2.lines[1].set_ydata(pred)
            else:
                self.ax2.plot(x, pred, label='prediction')
                self.ax2.plot(x, y, label='data')
                self.ax2.legend(loc='upper left')
            intermediates.append(pred)
            self.fig.canvas.draw()
            
loss = PlotLoss()
# %time model.fit(X_train,\
                Y_train,\
                nb_epoch=epochs,\
                batch_size=batch_size,\
                verbose=0,\
                callbacks=[loss])
# %matplotlib inline
# Out:
# <img src="data:image/png;base64,...">
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.223055). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.185731). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.182928). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.174529). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.187573). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.175655). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.188486). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.201165). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.188338). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.192915). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.247816). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.170642). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.173884). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.175262). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.179818). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.212806). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.184318). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.185689). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.189389). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.188217). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.196705). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.187945). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.188138). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.178347). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.199109). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.197058). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.185200). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.209148). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.190406). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.196043). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.271165). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.184074). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.220193). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.271537). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.226821). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.171652). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.327996). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.173694). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.173100). Check your callbacks.
#   % delta_t_median)
# //anaconda/lib/python3.5/site-packages/keras/callbacks.py:67: UserWarning: Method on_batch_end() is slow compared to the batch update (0.173195). Check your callbacks.
#   % delta_t_median)
# CPU times: user 8.99 s, sys: 227 ms, total: 9.22 s
# Wall time: 9.37 s

# %%
import matplotlib.animation as animation

fig = plt.figure()
plt.plot(x, y,  label='data')
line, = plt.plot(x, intermediates[0],  label='prediction')
plt.legend(loc='upper left')

def update_line(num):
    line.set_xdata(x)
    line.set_ydata(intermediates[num])
    return []

ani = animation.FuncAnimation(fig, update_line, len(intermediates),
                                   interval=50, blit=True)
ani.save('neuron.mp4', extra_args=['-vcodec', 'libx264'])

# %%
plt.plot(x, y, label='data')
plt.plot(x, intermediates[0], label='prediction')
plt.legend(loc='upper left')
plt.savefig('neuron_start.png')

# %%
pred = model.predict(X_train)
plt.plot(x, pred)
plt.plot(x, y)

# %%
# from keras.optimizers import RMSprop
# opti = RMSprop(lr=0.001, rho=0.9, epsilon=1e-06)
# model.compile(loss='mean_squared_error', optimizer=opti)

# %%
from keras import backend as K

def get_layer_outoput(layer):
    return K.function([model.layers[0].input],
                      [model.layers[layer].get_output(train=False)])

print('weigths')
print(model.layers[0].get_weights())
#print(model.layers[2].get_weights())
print()

# print('layers for input 0')
# print(get_layer_outoput(0)([X_train[0:1,:]])[0])
# print(get_layer_outoput(1)([X_train[0:1,:]])[0])
# #print(get_layer_outoput(2)([X_train[0:1,:]])[0])
# print()

# print('layers for input 0.5')
# print(get_layer_outoput(0)([X_train[5:6,:]])[0])
# print(get_layer_outoput(1)([X_train[5:6,:]])[0])
# #print(get_layer_outoput(2)([X_train[5:6,:]])[0])
# print()

# print('layers for input 1')
# print(get_layer_outoput(0)([X_train[10:11,:]])[0])
# print(get_layer_outoput(1)([X_train[10:11,:]])[0])
#print(get_layer_outoput(2)([X_train[10:11,:]])[0])
# Out:
# weigths
# [array([[ 0.84367132]], dtype=float32), array([-0.77101135], dtype=float32)]
